# %% [markdown]
#              ResNet (DNN) for Fashion MNIST Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add, Activation, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Flatten the images for DNN
x_train_flat = x_train.reshape(-1, 28*28)
x_test_flat = x_test.reshape(-1, 28*28)

# Visualize some samples
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add, Activation, BatchNormalization, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam

def create_dnn():
    inputs = Input(shape=(784,))
    
    x = Dense(1024, kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    x = Dense(512, kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    x = Dense(256, kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    x = Dense(128, kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    x = Dense(64, kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    outputs = Dense(10, activation='softmax')(x)
    return Model(inputs, outputs)

# Create model
dnn_model = create_dnn()

# Compile with lower learning rate and label smoothing
dnn_model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss=CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# Callbacks
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', patience=3, factor=0.5, verbose=1)

# Train the model
history = dnn_model.fit(
    x_train_flat, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=128,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 20s 38ms/step - accuracy: 0.5830 - loss: 1.4884 - val_accuracy: 0.8337 - val_loss: 0.8720 - learning_rate: 5.0000e-04
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.8253 - loss: 0.9578 - val_accuracy: 0.8442 - val_loss: 0.8392 - learning_rate: 5.0000e-04
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.8511 - loss: 0.8953 - val_accuracy: 0.8676 - val_loss: 0.7948 - learning_rate: 5.0000e-04
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.8635 - loss: 0.8559 - val_accuracy: 0.8724 - val_loss: 0.7799 - learning_rate: 5.0000e-04
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8762 - loss: 0.8239 - val_accuracy: 0.8639 - val_loss: 0.7993 - learning_rate: 5.0000e-04
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.8803 - loss: 0.8120 - val_accuracy: 0.8713 - val_loss: 0.7756 - learning_rate: 5.0000e-04
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.8815 - loss: 0.8010 - val_accuracy: 0.8782 - val_loss: 0.7672 - learning_rate: 5.0000e-04
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.8915 - loss: 0.7833 - val_accuracy: 0.8764 - val_loss: 0.7743 - learning_rate: 5.0000e-04
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.8924 - loss: 0.7758 - val_accuracy: 0.8895 - val_loss: 0.7468 - learning_rate: 5.0000e-04
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.8980 - loss: 0.7650 - val_accuracy: 0.8769 - val_loss: 0.7671 - learning_rate: 5.0000e-04
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9007 - loss: 0.7551 - val_accuracy: 0.8906 - val_loss: 0.7446 - learning_rate: 5.0000e-04
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9027 - loss: 0.7500 - val_accuracy: 0.8898 - val_loss: 0.7385 - learning_rate: 5.0000e-04
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9112 - loss: 0.7345 - val_accuracy: 0.8631 - val_loss: 0.7977 - learning_rate: 5.0000e-04
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9109 - loss: 0.7325 - val_accuracy: 0.8740 - val_loss: 0.7869 - learning_rate: 5.0000e-04
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9150 - loss: 0.7246
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 36ms/step - accuracy: 0.9150 - loss: 0.7246 - val_accuracy: 0.8871 - val_loss: 0.7529 - learning_rate: 5.0000e-04
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9217 - loss: 0.7067 - val_accuracy: 0.8974 - val_loss: 0.7287 - learning_rate: 2.5000e-04
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9282 - loss: 0.6972 - val_accuracy: 0.8985 - val_loss: 0.7284 - learning_rate: 2.5000e-04
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9280 - loss: 0.6944 - val_accuracy: 0.8979 - val_loss: 0.7307 - learning_rate: 2.5000e-04
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9347 - loss: 0.6835 - val_accuracy: 0.8968 - val_loss: 0.7372 - learning_rate: 2.5000e-04
# Epoch 20/50
# 374/375 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9351 - loss: 0.6826
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9351 - loss: 0.6826 - val_accuracy: 0.9007 - val_loss: 0.7284 - learning_rate: 2.5000e-04
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9412 - loss: 0.6682 - val_accuracy: 0.9008 - val_loss: 0.7284 - learning_rate: 1.2500e-04
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9427 - loss: 0.6644 - val_accuracy: 0.9016 - val_loss: 0.7279 - learning_rate: 1.2500e-04
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9449 - loss: 0.6603 - val_accuracy: 0.9046 - val_loss: 0.7249 - learning_rate: 1.2500e-04
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 41ms/step - accuracy: 0.9469 - loss: 0.6551 - val_accuracy: 0.9016 - val_loss: 0.7341 - learning_rate: 1.2500e-04
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9465 - loss: 0.6576 - val_accuracy: 0.9026 - val_loss: 0.7338 - learning_rate: 1.2500e-04
# Epoch 26/50
# 374/375 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9486 - loss: 0.6512
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9486 - loss: 0.6512 - val_accuracy: 0.9021 - val_loss: 0.7345 - learning_rate: 1.2500e-04
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 14s 38ms/step - accuracy: 0.9523 - loss: 0.6469 - val_accuracy: 0.9013 - val_loss: 0.7359 - learning_rate: 6.2500e-05
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.9533 - loss: 0.6433 - val_accuracy: 0.9038 - val_loss: 0.7288 - learning_rate: 6.2500e-05

# %%
# Plot training history
def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    plt.suptitle(title)
    
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    
    plt.show()

# %%
test_loss, test_acc = dnn_model.evaluate(x_test_flat, y_test)
print(f"Test Accuracy: {test_acc:.4f}")

# %%
# Evaluate on test set
dnn_test_loss, dnn_test_acc = dnn_model.evaluate(x_test_flat, y_test, verbose=0)
resnet_test_loss, resnet_test_acc = resnet_model.evaluate(x_test_flat, y_test, verbose=0)

# %%
print(f"Standard DNN Test Accuracy: {dnn_test_acc:.4f}")
print(f"ResNet-style DNN Test Accuracy: {resnet_test_acc:.4f}")
# Out:
# Standard DNN Test Accuracy: 0.7268
# ResNet-style DNN Test Accuracy: 0.8703

# %%
# Make predictions and visualize some results
def plot_predictions(model, x_test, y_test, num_images=5):
    predictions = model.predict(x_test)
    plt.figure(figsize=(15, 3*num_images))
    for i in range(num_images):
        plt.subplot(num_images, 1, i+1)
        plt.imshow(x_test[i].reshape(28, 28), cmap=plt.cm.binary)
        pred_label = np.argmax(predictions[i])
        true_label = np.argmax(y_test[i])
        color = 'green' if pred_label == true_label else 'red'
        plt.xlabel(f"Predicted: {class_names[pred_label]} (True: {class_names[true_label]})", color=color)
    plt.show()

print("\nStandard DNN Predictions:")
plot_predictions(dnn_model, x_test_flat, y_test)

print("\nResNet-style DNN Predictions:")
plot_predictions(resnet_model, x_test_flat, y_test)
# Out:
# Standard DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step
# ResNet-style DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
